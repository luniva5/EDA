# %%
import pandas as pd
import numpy as ap
import seaborn as sns

# %%
data = pd.read_csv("/Users/luni/Desktop/project/salary_analysis/Salary_Data.csv")

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
data.shape
# Out:
# (6704, 6)

# %%
data.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
data.nunique()
# Out:
# Age                     41
# Gender                   3
# Education Level          7
# Job Title              193
# Years of Experience     37
# Salary                 444
# dtype: int64

# %%
data['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan, "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %% [markdown]
# ### cleaning the data

# %%
data.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
dataset = data.drop_duplicates()

# %%
dataset.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
dataset.shape
# Out:
# (1787, 6)

# %%
dataset.describe()
# Out:
#                Age  Years of Experience         Salary
# count  1787.000000          1787.000000    1787.000000
# mean     35.139899             9.156128  113184.659765
# std       8.213045             6.844924   51596.536766
# min      21.000000             0.000000     350.000000
# 25%      29.000000             3.000000   70000.000000
# 50%      33.000000             8.000000  110000.000000
# 75%      41.000000            13.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %% [markdown]
# ## Relationship Analysis

# %%
corelation = dataset.corr()
# Out:
# /var/folders/h5/2fvfd8xj0qb95x1zvqmqc6y40000gn/T/ipykernel_85113/121483462.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corelation = dataset.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(dataset)

# %%
sns.relplot(x= 'Salary', y= 'Years of Experience', hue='Education Level', data=dataset)

# %%
sns.relplot(x= 'Salary', y= 'Years of Experience', hue='Gender', data=dataset)

# %%
sns.displot(dataset['Salary'], bins=7)

# %%
sns.catplot(x='Salary', y='Education Level', kind= 'box', data=dataset)

# %%
sns.catplot(x='Gender', y='Salary', kind= 'box', data=dataset)
